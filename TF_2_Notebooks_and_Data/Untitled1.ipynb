# %%
print("Hello")
# Out:
# Hello

# %%
import tensorflow as tf
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\fakthar\AppData\Local\anaconda3\envs\mytfenv\lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\fakthar\AppData\Local\Temp\ipykernel_7248\3793406994.py", line 1, in <module>
#     import tensorflow as tf
#   File "C:\Users\fakthar\AppData\Local\anaconda3\envs\mytfenv\lib\site-packages\tensorflow\__init__.py", line 98, in <module>
#     from tensorflow_core import *
#   File "C:\Users\fakthar\AppData\Local\anaconda3\envs\mytfenv\lib\site-packages\tensorflow_core\__init__.py", line 40, in <module>
# ...
